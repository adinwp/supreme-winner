# %% [markdown]
# <a href="https://colab.research.google.com/github/adinwp/supreme-winner/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1ZvpUHNlrwr8Mseigi8jrJxME3UF7GEQ3JgokIEi7fwo/edit#gid=1383611653'
sheet_url_trf = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
df = pd.read_csv(sheet_url_trf)
df
# Out:
#                                               dma  geoCode  2004+cancer  \
# 0                              Portland-Auburn ME      500           44
# 1                                     New York NY      501           47
# 2                                   Binghamton NY      502           48
# 3                                        Macon GA      503           44
# 4                                 Philadelphia PA      504           52
# ..                                            ...      ...          ...
# 205  Santa Barbara-Santa Maria-San Luis Obispo CA      855           35
# 206                Sacramento-Stockton-Modesto CA      862           40
# 207                             Fresno-Visalia CA      866           34
# 208                              Chico-Redding CA      868           36
# 209                                    Spokane WA      881           44
#
#      2004+cardiovascular  2004+stroke  2004+depression  2004+rehab  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                               dma  geoCode  2004+cancer  \
# 0                              Portland-Auburn ME      500           44
# 1                                     New York NY      501           47
# 2                                   Binghamton NY      502           48
# 3                                        Macon GA      503           44
# 4                                 Philadelphia PA      504           52
# ..                                            ...      ...          ...
# 205  Santa Barbara-Santa Maria-San Luis Obispo CA      855           35
# 206                Sacramento-Stockton-Modesto CA      862           40
# 207                             Fresno-Visalia CA      866           34
# 208                              Chico-Redding CA      868           36
# 209                                    Spokane WA      881           44
#
#      2004+cardiovascular  2004+stroke  2004+depression  2004+rehab  \
# ...

# %%
x = df['2004+diabetes']
y = df['2004+obesity']

# %%
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='s')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %%
# (r,p_value) = stats.pearsonr(x, y)
# print(r)
# print(p_value)
